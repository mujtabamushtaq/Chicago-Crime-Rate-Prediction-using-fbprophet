# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from fbprophet import Prophet
# Out:
# ERROR:fbprophet:Importing plotly failed. Interactive plots will not work.

# %%
df_1 = pd.read_csv("Chicago_Crimes_2005_to_2007.csv", error_bad_lines = False)
df_2 = pd.read_csv("Chicago_Crimes_2008_to_2011.csv", error_bad_lines = False)
df_3 = pd.read_csv("Chicago_Crimes_2012_to_2017.csv", error_bad_lines = False)
# Out:
# b'Skipping line 533719: expected 23 fields, saw 24\n'
# b'Skipping line 1149094: expected 23 fields, saw 41\n'

# %%
print(df_1.shape)
print(df_2.shape)
print(df_3.shape)
# Out:
# (1872343, 23)
# (2688710, 23)
# (1456714, 23)

# %%
chicago_crime_df = pd.concat([df_1,df_2,df_3])

# %%
chicago_crime_df.shape
# Out:
# (6017767, 23)

# %%
chicago_crime_df.head()
# Out:
#    Unnamed: 0       ID Case Number                    Date  \
# 0           0  4673626    HM274058  04/02/2006 01:00:00 PM
# 1           1  4673627    HM202199  02/26/2006 01:40:48 PM
# 2           2  4673628    HM113861  01/08/2006 11:16:00 PM
# 3           4  4673629    HM274049  04/05/2006 06:45:00 PM
# 4           5  4673630    HM187120  02/17/2006 09:03:14 PM
#
#                  Block  IUCR   Primary Type                   Description  \
# 0    055XX N MANGO AVE  2825  OTHER OFFENSE       HARASSMENT BY TELEPHONE
# 1   065XX S RHODES AVE  2017      NARCOTICS            MANU/DELIVER:CRACK
# 2      013XX E 69TH ST  051A        ASSAULT           AGGRAVATED: HANDGUN
# 3  061XX W NEWPORT AVE  0460        BATTERY                        SIMPLE
# 4      037XX W 60TH ST  1811      NARCOTICS  POSS: CANNABIS 30GMS OR LESS
#
#   Location Description  Arrest  ...  Ward  Community Area  FBI Code  \
# 0            RESIDENCE   False  ...  45.0            11.0        26
# ...

# %%
chicago_crime_df.tail()
# Out:
#          Unnamed: 0        ID Case Number                    Date  \
# 1456709     6250330  10508679    HZ250507  05/03/2016 11:33:00 PM
# 1456710     6251089  10508680    HZ250491  05/03/2016 11:30:00 PM
# 1456711     6251349  10508681    HZ250479  05/03/2016 12:15:00 AM
# 1456712     6253257  10508690    HZ250370  05/03/2016 09:07:00 PM
# 1456713     6253474  10508692    HZ250517  05/03/2016 11:38:00 PM
#
#                         Block  IUCR     Primary Type              Description  \
# 1456709       026XX W 23RD PL  0486          BATTERY  DOMESTIC BATTERY SIMPLE
# 1456710   073XX S HARVARD AVE  1310  CRIMINAL DAMAGE              TO PROPERTY
# 1456711       024XX W 63RD ST  041A          BATTERY      AGGRAVATED: HANDGUN
# 1456712  082XX S EXCHANGE AVE  0486          BATTERY  DOMESTIC BATTERY SIMPLE
# 1456713       001XX E 75TH ST  5007    OTHER OFFENSE  OTHER WEAPONS VIOLATION
#
#                    Location Description  Arrest  ...  Ward  Community Area  \
# ...

# %%
plt.figure(figsize = (10,10))
sns.heatmap(chicago_crime_df.isnull(), cbar = False, cmap = 'YlGnBu')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-13-490a17e7eba0> in <module>
#       1 plt.figure(figsize = (10,10))
# ----> 2 sns.heatmap(chicago_crime_df.isnull(), cbar = False, cmap = 'YlGnBu')
#
# ~\.conda\envs\office\lib\site-packages\seaborn\matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     526     if square:
#     527         ax.set_aspect("equal")
# --> 528     plotter.plot(ax, cbar_ax, kwargs)
#     529     return ax
#     530
#
# ~\.conda\envs\office\lib\site-packages\seaborn\matrix.py in plot(self, ax, cax, kws)
#     316         # Possibly rotate them if they overlap
#     317         if hasattr(ax.figure.canvas, "get_renderer"):
# --> 318             ax.figure.draw(ax.figure.canvas.get_renderer())
# ...

# %%
chicago_crime_df.drop(['Unnamed: 0', 'ID', 'Case Number', 'IUCR', 'X Coordinate', 'Y Coordinate', 'FBI Code', 'Updated On', 'Year', 'Beat', 'Ward', 'Latitude', 'Longitude', 'Location', 'Community Area', 'District'], inplace = True, axis = 1)

# %%
chicago_crime_df.shape
# Out:
# (6017767, 7)

# %%
chicago_crime_df.Date = pd.to_datetime(chicago_crime_df.Date, format = "%m/%d/%Y %I:%M:%S %p")

# %%
chicago_crime_df['Primary Type'].value_counts()
# Out:
# THEFT                                1245111
# BATTERY                              1079178
# CRIMINAL DAMAGE                       702702
# NARCOTICS                             674831
# BURGLARY                              369056
# OTHER OFFENSE                         368169
# ASSAULT                               360244
# MOTOR VEHICLE THEFT                   271624
# ROBBERY                               229467
# DECEPTIVE PRACTICE                    225180
# CRIMINAL TRESPASS                     171596
# PROSTITUTION                           60735
# WEAPONS VIOLATION                      60335
# PUBLIC PEACE VIOLATION                 48403
# OFFENSE INVOLVING CHILDREN             40260
# CRIM SEXUAL ASSAULT                    22789
# SEX OFFENSE                            20172
# GAMBLING                               14755
# INTERFERENCE WITH PUBLIC OFFICER       14009
# LIQUOR LAW VIOLATION                   12129
# ARSON                                   9269
# ...

# %%
chicago_crime_df['Primary Type'].value_counts().iloc[:15]
# Out:
# THEFT                         1245111
# BATTERY                       1079178
# CRIMINAL DAMAGE                702702
# NARCOTICS                      674831
# BURGLARY                       369056
# OTHER OFFENSE                  368169
# ASSAULT                        360244
# MOTOR VEHICLE THEFT            271624
# ROBBERY                        229467
# DECEPTIVE PRACTICE             225180
# CRIMINAL TRESPASS              171596
# PROSTITUTION                    60735
# WEAPONS VIOLATION               60335
# PUBLIC PEACE VIOLATION          48403
# OFFENSE INVOLVING CHILDREN      40260
# Name: Primary Type, dtype: int64

# %%
order = chicago_crime_df['Primary Type'].value_counts().iloc[:15].index
order
# Out:
# Index(['THEFT', 'BATTERY', 'CRIMINAL DAMAGE', 'NARCOTICS', 'BURGLARY',
#        'OTHER OFFENSE', 'ASSAULT', 'MOTOR VEHICLE THEFT', 'ROBBERY',
#        'DECEPTIVE PRACTICE', 'CRIMINAL TRESPASS', 'PROSTITUTION',
#        'WEAPONS VIOLATION', 'PUBLIC PEACE VIOLATION',
#        'OFFENSE INVOLVING CHILDREN'],
#       dtype='object')

# %%
plt.figure(figsize = (15,10))
sns.countplot(y = 'Primary Type', data = chicago_crime_df, order = order)

# %%
plt.figure(figsize = (15,10))
sns.countplot(y = 'Location Description', data = chicago_crime_df, order = chicago_crime_df['Location Description'].value_counts().iloc[:15].index)

# %%
chicago_crime_df.index = pd.DatetimeIndex(chicago_crime_df.Date)

# %%
chicago_crime_df
# Out:
#                                    Date                 Block  \
# Date
# 2006-04-02 13:00:00 2006-04-02 13:00:00     055XX N MANGO AVE
# 2006-02-26 13:40:48 2006-02-26 13:40:48    065XX S RHODES AVE
# 2006-01-08 23:16:00 2006-01-08 23:16:00       013XX E 69TH ST
# 2006-04-05 18:45:00 2006-04-05 18:45:00   061XX W NEWPORT AVE
# 2006-02-17 21:03:14 2006-02-17 21:03:14       037XX W 60TH ST
# ...                                 ...                   ...
# 2016-05-03 23:33:00 2016-05-03 23:33:00       026XX W 23RD PL
# 2016-05-03 23:30:00 2016-05-03 23:30:00   073XX S HARVARD AVE
# 2016-05-03 00:15:00 2016-05-03 00:15:00       024XX W 63RD ST
# 2016-05-03 21:07:00 2016-05-03 21:07:00  082XX S EXCHANGE AVE
# 2016-05-03 23:38:00 2016-05-03 23:38:00       001XX E 75TH ST
#
#                         Primary Type                   Description  \
# Date
# 2006-04-02 13:00:00    OTHER OFFENSE       HARASSMENT BY TELEPHONE
# 2006-02-26 13:40:48        NARCOTICS            MANU/DELIVER:CRACK
# ...

# %%
chicago_crime_df.resample('Y').size()
# Out:
# Date
# 2005-12-31    455811
# 2006-12-31    794684
# 2007-12-31    621848
# 2008-12-31    852053
# 2009-12-31    783900
# 2010-12-31    700691
# 2011-12-31    352066
# 2012-12-31    335670
# 2013-12-31    306703
# 2014-12-31    274527
# 2015-12-31    262995
# 2016-12-31    265462
# 2017-12-31     11357
# Freq: A-DEC, dtype: int64

# %%
plt.plot(chicago_crime_df.resample('Y').size())
plt.title('Crimes per Year')
plt.xlabel('Year')
plt.ylabel('Crimes')
# Out:
# Text(0, 0.5, 'Crimes')

# %%
plt.plot(chicago_crime_df.resample('M').size())
plt.title('Crimes per Month')
plt.xlabel('Month')
plt.ylabel('Crimes')
# Out:
# Text(0, 0.5, 'Crimes')

# %%
plt.plot(chicago_crime_df.resample('Q').size())
plt.title('Crimes per Quarter')
plt.xlabel('Quarter')
plt.ylabel('Crimes')
# Out:
# Text(0, 0.5, 'Crimes')

# %%
chicago_prophet = chicago_crime_df.resample('M').size().reset_index()
chicago_prophet
# Out:
#           Date      0
# 0   2005-01-31  33983
# 1   2005-02-28  32042
# 2   2005-03-31  36970
# 3   2005-04-30  38963
# 4   2005-05-31  40572
# ..         ...    ...
# 140 2016-09-30  23235
# 141 2016-10-31  23314
# 142 2016-11-30  21140
# 143 2016-12-31  19580
# 144 2017-01-31  11357
#
# [145 rows x 2 columns]

# %%
chicago_prophet.columns =  ['Date', 'Crime Count']
chicago_prophet
# Out:
#           Date  Crime Count
# 0   2005-01-31        33983
# 1   2005-02-28        32042
# 2   2005-03-31        36970
# 3   2005-04-30        38963
# 4   2005-05-31        40572
# ..         ...          ...
# 140 2016-09-30        23235
# 141 2016-10-31        23314
# 142 2016-11-30        21140
# 143 2016-12-31        19580
# 144 2017-01-31        11357
#
# [145 rows x 2 columns]

# %%
chicago_prophet_df = chicago_prophet.rename(columns = {'Date':'ds', 'Crime Count':'y'})

# %%
model = Prophet()
model.fit(chicago_prophet_df)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future_df = model.make_future_dataframe(periods=365)
forecast = model.predict(future_df)
forecast
# Out:
#             ds         trend    yhat_lower    yhat_upper   trend_lower  \
# 0   2005-01-31  60454.773642  38586.289179  72254.749037  60454.773642
# 1   2005-02-28  60322.370911  34453.755928  67589.291420  60322.370911
# 2   2005-03-31  60175.782173  42120.755753  74744.308071  60175.782173
# 3   2005-04-30  60033.922104  43524.315325  77383.352471  60033.922104
# 4   2005-05-31  59887.333366  49976.255739  82791.804914  59887.333366
# ..         ...           ...           ...           ...           ...
# 505 2018-01-27  10104.146683 -13019.421035  21839.018697   9937.663301
# 506 2018-01-28  10091.080010 -11408.270331  21697.815857   9924.081369
# 507 2018-01-29  10078.013336 -11679.664319  21551.961928   9910.449499
# 508 2018-01-30  10064.946663 -13200.640782  21240.880458   9896.817629
# 509 2018-01-31  10051.879989 -10405.732290  22123.984585   9883.185759
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# ...

# %%
figure = model.plot(forecast, xlabel='Date', ylabel='Crime Rate')

# %%
figure = model.plot_components(forecast)

# %%
future_df = model.make_future_dataframe(periods=730)
forecast = model.predict(future_df)
figure = model.plot(forecast, xlabel='Date', ylabel='Crime Rate')
